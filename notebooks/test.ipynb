# %%
import sys
import os
import time

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from config import XML_DIR
from envs_converted.hopper_4 import ModularEnv

# %%
xml = os.path.join(XML_DIR, "hopper_4.xml")  
env = ModularEnv(xml=xml, render_mode="human")

obs, info = env.reset(seed=42)
for _ in range(500):
    a = env.action_space.sample()
    obs, r, term, trunc, info = env.step(a)
    env.render()
    time.sleep(0.01)
    if term or trunc:
        break
env.close()
# Out:
# You are using a GLFW raw input patch. This is not the official GLFW library.

# %% [markdown]
# # utils test

# %%
import sys
import os
import time

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from utils import registerEnvs
import gymnasium as gym

# %%
registerEnvs(
    env_names=["hopper_4"],
    max_episode_steps=2000,
    custom_xml=None,
)
# Out:
# (4, 19, 1.0)
